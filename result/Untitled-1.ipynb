# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('/home/said/courses/Projetinfo/sports_scr/result/experiments.txt', sep='\t')

# %%
df.sort_values(by='cer')
# Out:
#          engine  orientation   clip  correct_names       wer       cer
# 3         doctr         True  False          False  0.707491  0.477253
# 11      easyocr         True  False          False  0.667134  0.484360
# 2         doctr         True  False           True  0.718889  0.499732
# 10      easyocr         True  False           True  0.694497  0.529069
# 7         doctr        False  False          False  0.751845  0.552208
# 13      easyocr        False   True          False  0.740732  0.569612
# 5         doctr        False   True          False  0.759056  0.571127
# 15      easyocr        False  False          False  0.742778  0.575124
# 9       easyocr         True   True          False  0.750564  0.592171
# 1         doctr         True   True          False  0.802892  0.600602
# 4         doctr        False   True           True  0.814815  0.618220
# 8       easyocr         True   True           True  0.822434  0.644812
# ...
